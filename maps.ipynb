# %%
import rioxarray as rxr
import numpy as np
import pandas as pd
import geopandas as gpd
import rasterio
import os

# %%
#read csv file
df = pd.read_csv('stations.csv')

# %%
df
# Out:
#                                                     Id               Name  \
# 0    http://meta.icos-cp.eu/resources/stations/ES_D...  Schechenfilz Nord
# 1    http://meta.icos-cp.eu/resources/stations/ES_F...           Hyytiala
# 2    http://meta.icos-cp.eu/resources/stations/ES_F...              Bilos
# 3    http://meta.icos-cp.eu/resources/stations/ES_S...        Svartberget
# 4     http://meta.icos-cp.eu/resources/stations/AS_LMP          Lampedusa
# ..                                                 ...                ...
# 173  http://meta.icos-cp.eu/resources/stations/ES_F...           Lettosuo
# 174   http://meta.icos-cp.eu/resources/stations/AS_HTM         Hyltemossa
# 175  http://meta.icos-cp.eu/resources/stations/OS_48MB           MIRAMARE
# 176                                             SE-Oes     Östergarnsholm
# 177   http://meta.icos-cp.eu/resources/stations/AS_RGL         Ridge Hill
#
#                                                Country             Position  \
# 0                                         Germany (DE)     11.3275 47.80639
# 1                                         Finland (FI)    24.29477 61.84741
# 2                                          France (FR)  -0.956092 44.493652
# 3                                          Sweden (SE)     19.7745 64.25611
# 4                                           Italy (IT)      12.6322 35.5181
# ..                                                 ...                  ...
# 173                                       Finland (FI)    23.95952 60.64183
# 174                                        Sweden (SE)      13.4189 56.0976
# 175                                         Italy (IT)        13.708 45.698
# 176                                        Sweden (SE)     18.98415 57.4301
# 177  United Kingdom of Great Britain and Northern I...      -2.5399 51.9975
#
#                           PI names                     Site type  \
# 0                           Schmid                       wetland
# 1                       Mammarella  evergreen needleleaf forests
# 2                            Domec  evergreen needleleaf forests
# 3                           Peichl  evergreen needleleaf forests
# 4    Di Iorio Piacentino Sferlazzo                 marine remote
# ..                             ...                           ...
# 173                    Korkiakoski  evergreen needleleaf forests
# 174               Biermann Heliasz                    tall tower
# 175                          Giani                 fixed station
# 176                     Rutgersson                  water bodies
# 177                   Pitt Stanley                    tall tower
#
#      Elevation above sea Station class Labeling date
# 0                 590.00    Associated           NaN
# 1                 181.00             1    2018-11-30
# 2                  39.18             2    2019-11-21
# 3                 267.00             2    2019-05-22
# 4                  45.00             2    2020-05-27
# ..                   ...           ...           ...
# 173               125.00    Associated    2018-11-30
# 174               115.00             1    2018-05-31
# 175                -2.00             2    2022-11-23
# 176                  NaN    Associated           NaN
# 177               207.00             2    2022-05-18
#
# [178 rows x 9 columns]

# %%
# Split the "Position" column into two new columns: Lon and Lat
df[['Longitude', 'Latitude']] = df['Position'].str.split(' ', expand=True)

# Convert them to float
df['Longitude'] = df['Longitude'].astype(float)
df['Latitude'] = df['Latitude'].astype(float)

# Convert to GeoDataFrame
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.Longitude, df.Latitude))

# Set the coordinate reference system (CRS) to WGS84 (EPSG:4326)
gdf.set_crs(epsg=4326, inplace=True)

# Display the first rows of the GeoDataFrame
gdf.head()
# Out:
#                                                   Id               Name  \
# 0  http://meta.icos-cp.eu/resources/stations/ES_D...  Schechenfilz Nord
# 1  http://meta.icos-cp.eu/resources/stations/ES_F...           Hyytiala
# 2  http://meta.icos-cp.eu/resources/stations/ES_F...              Bilos
# 3  http://meta.icos-cp.eu/resources/stations/ES_S...        Svartberget
# 4   http://meta.icos-cp.eu/resources/stations/AS_LMP          Lampedusa
#
#         Country             Position                       PI names  \
# 0  Germany (DE)     11.3275 47.80639                         Schmid
# 1  Finland (FI)    24.29477 61.84741                     Mammarella
# 2   France (FR)  -0.956092 44.493652                          Domec
# 3   Sweden (SE)     19.7745 64.25611                         Peichl
# 4    Italy (IT)      12.6322 35.5181  Di Iorio Piacentino Sferlazzo
#
#                       Site type  Elevation above sea Station class  \
# 0                       wetland               590.00    Associated
# 1  evergreen needleleaf forests               181.00             1
# 2  evergreen needleleaf forests                39.18             2
# 3  evergreen needleleaf forests               267.00             2
# 4                 marine remote                45.00             2
#
#   Labeling date  Longitude   Latitude                   geometry
# 0           NaN  11.327500  47.806390   POINT (11.3275 47.80639)
# 1    2018-11-30  24.294770  61.847410  POINT (24.29477 61.84741)
# 2    2019-11-21  -0.956092  44.493652  POINT (-0.95609 44.49365)
# 3    2019-05-22  19.774500  64.256110   POINT (19.7745 64.25611)
# 4    2020-05-27  12.632200  35.518100    POINT (12.6322 35.5181)

# %%
#print all different site types
site_types = gdf['Site type'].unique()

# %%
site_types
# Out:
# array(['wetland', 'evergreen needleleaf forests', 'marine remote',
#        'open shrublands', 'grasslands', 'urban and built-up lands',
#        'permanent wetlands', 'deciduous needleleaf forests', 'soop',
#        'mountain', 'fixed station', 'water bodies', 'coastal',
#        'evergreen broadleaf forests', 'non-forested island on sea',
#        'croplands', 'deciduous broadleaf forests', 'closed shrublands',
#        'tall tower', 'surface  land', 'savannas', 'forest', 'ground',
#        '(tall) tower', 'continental', 'mixed forests',
#        'coastal/continental', 'remote arctic', 'profiling station',
#        'tower', 'grassland'], dtype=object)

# %%
#filter site_types on the word forest
forest_sites = gdf[gdf['Site type'].str.contains('forest', case=False)]

# %%
forest_sites
# Out:
#                                                     Id  \
# 1    http://meta.icos-cp.eu/resources/stations/ES_F...
# 2    http://meta.icos-cp.eu/resources/stations/ES_F...
# 3    http://meta.icos-cp.eu/resources/stations/ES_S...
# 8    http://meta.icos-cp.eu/resources/stations/ES_S...
# 10   http://meta.icos-cp.eu/resources/stations/ES_I...
# 14   http://meta.icos-cp.eu/resources/stations/ES_C...
# 17   http://meta.icos-cp.eu/resources/stations/ES_N...
# 23   http://meta.icos-cp.eu/resources/stations/ES_F...
# 26   http://meta.icos-cp.eu/resources/stations/ES_G...
# 27   http://meta.icos-cp.eu/resources/stations/ES_I...
# 28    http://meta.icos-cp.eu/resources/stations/AS_UTO
# 31   http://meta.icos-cp.eu/resources/stations/ES_F...
# 43   http://meta.icos-cp.eu/resources/stations/ES_F...
# 47   http://meta.icos-cp.eu/resources/stations/ES_B...
# 56   http://meta.icos-cp.eu/resources/stations/ES_I...
# 59   http://meta.icos-cp.eu/resources/stations/ES_G...
# 61   http://meta.icos-cp.eu/resources/stations/ES_D...
# 63   http://meta.icos-cp.eu/resources/stations/ES_D...
# 78   http://meta.icos-cp.eu/resources/stations/ES_I...
# 80   http://meta.icos-cp.eu/resources/stations/ES_D...
# 87   http://meta.icos-cp.eu/resources/stations/ES_D...
# 89   http://meta.icos-cp.eu/resources/stations/ES_I...
# 99   http://meta.icos-cp.eu/resources/stations/ES_I...
# 107  http://meta.icos-cp.eu/resources/stations/ES_I...
# 112  http://meta.icos-cp.eu/resources/stations/ES_D...
# 123  http://meta.icos-cp.eu/resources/stations/ES_F...
# 127  http://meta.icos-cp.eu/resources/stations/ES_I...
# 129  http://meta.icos-cp.eu/resources/stations/ES_C...
# 132  http://meta.icos-cp.eu/resources/stations/ES_N...
# 134  http://meta.icos-cp.eu/resources/stations/ES_B...
# 138  http://meta.icos-cp.eu/resources/stations/ES_C...
# 139  http://meta.icos-cp.eu/resources/stations/ES_D...
# 142  http://meta.icos-cp.eu/resources/stations/ES_S...
# 148  http://meta.icos-cp.eu/resources/stations/ES_C...
# 149  http://meta.icos-cp.eu/resources/stations/ES_F...
# 150  http://meta.icos-cp.eu/resources/stations/ES_D...
# 161  http://meta.icos-cp.eu/resources/stations/ES_F...
# 162  http://meta.icos-cp.eu/resources/stations/ES_F...
# 163  http://meta.icos-cp.eu/resources/stations/ES_D...
# 164  http://meta.icos-cp.eu/resources/stations/ES_D...
# 166                                             IT-Col
# 168  http://meta.icos-cp.eu/resources/stations/ES_D...
# 169  http://meta.icos-cp.eu/resources/stations/ES_F...
# 173  http://meta.icos-cp.eu/resources/stations/ES_F...
#
#                             Name                                     Country  \
# 1                       Hyytiala                                Finland (FI)
# 2                          Bilos                                 France (FR)
# 3                    Svartberget                                 Sweden (SE)
# 8                        Norunda                                 Sweden (SE)
# 10                    Torgnon-LD                                  Italy (IT)
# 14              Bily Kriz forest                         Czech Republic (CZ)
# 17                        Hurdal                                 Norway (NO)
# 23                     Sodankyla                                Finland (FI)
# 26                      Guyaflux                          French Guiana (GF)
# 27                         Renon                                  Italy (IT)
# 28              Utö - Baltic sea                                Finland (FI)
# 31         Fontainebleau-Barbeau                                 France (FR)
# 43            Montiers sur Saulx                                 France (FR)
# 47                    Brasschaat                                Belgium (BE)
# 56                 San Rossore 2                                  Italy (IT)
# 59                      Pertouli                                 Greece (GR)
# 61                     Wustebach                                Germany (DE)
# 63                    Mooseurach                                Germany (DE)
# 78               Castelporziano2                                  Italy (IT)
# 80                         Risoe                                Denmark (DK)
# 87                    Hohes Holz                                Germany (DE)
# 89   Parco Urbano di Capodimonte                                  Italy (IT)
# 99                        Dooary                                Ireland (IE)
# 107                    Lampedusa                                  Italy (IT)
# 112                     Hartheim                                Germany (DE)
# 123                       Varrio                                Finland (FI)
# 127                Bosco Fontana                                  Italy (IT)
# 129                        Davos                            Switzerland (CH)
# 132                       Loobos                            Netherlands (NL)
# 134                     Vielsalm                                Belgium (BE)
# 138                     Yangambi  Congo  the Democratic Republic of the (CD)
# 139                     Tharandt                                Germany (DE)
# 142                   Hyltemossa                                 Sweden (SE)
# 148                      Lanzhot                         Czech Republic (CZ)
# 149                    Puechabon                                 France (FR)
# 150                      Hainich                                Germany (DE)
# 161                        Hesse                                 France (FR)
# 162                   Kenttarova                                Finland (FI)
# 163                        Soroe                                Denmark (DK)
# 164                     Hetzdorf                                Germany (DE)
# 166                   Collelongo                                  Italy (IT)
# 168                    Kienhorst                                Germany (DE)
# 169                 Font-Blanche                                 France (FR)
# 173                     Lettosuo                                Finland (FI)
#
#                 Position         PI names                     Site type  \
# 1      24.29477 61.84741       Mammarella  evergreen needleleaf forests
# 2    -0.956092 44.493652            Domec  evergreen needleleaf forests
# 3       19.7745 64.25611           Peichl  evergreen needleleaf forests
# 8      17.479504 60.0865            Kljun  evergreen needleleaf forests
# 10      7.56089 45.82376         Galvagno  deciduous needleleaf forests
# 14   18.536882 49.502075            Šigut  evergreen needleleaf forests
# 17     11.07949 60.37163            Lange  evergreen needleleaf forests
# 23     26.63859 67.36239           Aurela  evergreen needleleaf forests
# 26       -52.9248 5.2787            Bonal   evergreen broadleaf forests
# 27     11.43369 46.58686       Montagnani  evergreen needleleaf forests
# 28       21.3672 59.7839  Hatakka Laurila    non-forested island on sea
# 31    2.780096 48.476357       Berveiller   deciduous broadleaf forests
# 43      5.31187 48.53816             Galy                        forest
# 47      4.51984 51.30761         Janssens  evergreen needleleaf forests
# 56     10.29091 43.73202           Arriga  evergreen needleleaf forests
# 59       21.4989 39.5434            Gitas  evergreen needleleaf forests
# 61    6.3309627 50.50493          Schmidt  evergreen needleleaf forests
# 63    11.456168 47.80918          Drösler  evergreen needleleaf forests
# 78   12.357293 41.704266            Fares                 mixed forests
# 80   12.101398 55.680683            Ibrom   deciduous broadleaf forests
# 87     11.22235 52.08656      Hildebrandt   deciduous broadleaf forests
# 89       14.2504 40.8741      Calfapietra                        forest
# 99    -7.253945 52.94873            Tobin   deciduous broadleaf forests
# 107      12.5365 35.5252           Meloni                        forest
# 112        7.5981 47.933         Christen                 mixed forests
# 123        29.61 67.7549           Kolari  evergreen needleleaf forests
# 127  10.741966 45.197754           Gerosa   deciduous broadleaf forests
# 129     9.85591 46.81533     Feigenwinter  evergreen needleleaf forests
# 132    5.74355 52.166447    van der Molen  evergreen needleleaf forests
# 134   5.998099 50.304962           Vincke                 mixed forests
# 138   24.502472 0.814444           Boeckx                 mixed forests
# 139    13.56515 50.96256           Mauder  evergreen needleleaf forests
# 142    13.41897 56.09763          Heliasz  evergreen needleleaf forests
# 148   16.946331 48.68155         Kowalska   deciduous broadleaf forests
# 149       3.5957 43.7413         Limousin   evergreen broadleaf forests
# 150  10.452089 51.079407            Knohl   deciduous broadleaf forests
# 161      7.06465 48.6741            Cuntz   deciduous broadleaf forests
# 162    24.24301 67.98721           Aurela  evergreen needleleaf forests
# 163   11.644645 55.48587            Ibrom   deciduous broadleaf forests
# 164    13.48978 50.96381           Mauder   deciduous broadleaf forests
# 166      13.5881 41.8494        Matteucci   deciduous broadleaf forests
# 168    52.97343 13.64393        Hentschel                        forest
# 169     5.67865 43.24079          Simioni  evergreen needleleaf forests
# 173    23.95952 60.64183      Korkiakoski  evergreen needleleaf forests
#
#      Elevation above sea Station class Labeling date  Longitude   Latitude  \
# 1               181.0000             1    2018-11-30  24.294770  61.847410
# 2                39.1800             2    2019-11-21  -0.956092  44.493652
# 3               267.0000             2    2019-05-22  19.774500  64.256110
# 8                45.0000             2    2018-11-30  17.479504  60.086500
# 10             2100.0000    Associated    2024-05-14   7.560890  45.823760
# 14              875.0000             2    2022-05-18  18.536882  49.502075
# 17              275.1308             2    2023-11-15  11.079490  60.371630
# 23              180.0000             1    2023-05-23  26.638590  67.362390
# 26               40.0000    Associated    2019-11-21 -52.924800   5.278700
# 27             1735.6000             2    2021-11-17  11.433690  46.586860
# 28                8.0000             2    2019-05-22  21.367200  59.783900
# 31              103.0000             1    2019-11-21   2.780096  48.476357
# 43              383.0000    Associated           NaN   5.311870  48.538160
# 47               16.0000             1    2020-11-17   4.519840  51.307610
# 56                4.0000             2    2019-11-21  10.290910  43.732020
# 59             1350.0000             2           NaN  21.498900  39.543400
# 61              610.0000    Associated    2022-05-18   6.330963  50.504930
# 63              602.0700    Associated    2022-05-18  11.456168  47.809180
# 78               19.0000             1    2021-05-25  12.357293  41.704266
# 80               40.0000    Associated    2024-11-06  12.101398  55.680683
# 87              193.0000             1    2019-05-22  11.222350  52.086560
# 89              148.0000    Associated           NaN  14.250400  40.874100
# 99                   NaN             2           NaN  -7.253945  52.948730
# 107                  NaN    Associated           NaN  12.536500  35.525200
# 112             201.0000    Associated    2022-05-18   7.598100  47.933000
# 123             395.0000    Associated    2018-11-30  29.610000  67.754900
# 127              23.0000    Associated    2021-05-25  10.741966  45.197754
# 129            1689.0000             1    2019-11-21   9.855910  46.815330
# 132              33.0000             2    2023-05-23   5.743550  52.166447
# 134             490.0000             2    2020-11-17   5.998099  50.304962
# 138             466.0000    Associated    2022-11-23  24.502472   0.814444
# 139             380.0000             1    2020-11-17  13.565150  50.962560
# 142             115.0000             2    2018-05-31  13.418970  56.097630
# 148             150.0000             1    2022-05-18  16.946331  48.681550
# 149             271.0000             2    2021-11-17   3.595700  43.741300
# 150             438.7000    Associated    2020-05-27  10.452089  51.079407
# 161             310.0000             1    2022-05-18   7.064650  48.674100
# 162             347.0000    Associated    2021-05-25  24.243010  67.987210
# 163              40.0000             1    2021-11-17  11.644645  55.485870
# 164             395.0000    Associated    2023-05-23  13.489780  50.963810
# 166                  NaN    Associated           NaN  13.588100  41.849400
# 168              63.0000    Associated           NaN  52.973430  13.643930
# 169             436.0000             2    2022-11-23   5.678650  43.240790
# 173             125.0000    Associated    2018-11-30  23.959520  60.641830
#
#                       geometry
# 1    POINT (24.29477 61.84741)
# 2    POINT (-0.95609 44.49365)
# 3     POINT (19.7745 64.25611)
# 8      POINT (17.4795 60.0865)
# 10    POINT (7.56089 45.82376)
# 14   POINT (18.53688 49.50208)
# 17   POINT (11.07949 60.37163)
# 23   POINT (26.63859 67.36239)
# 26     POINT (-52.9248 5.2787)
# 27   POINT (11.43369 46.58686)
# 28     POINT (21.3672 59.7839)
# 31     POINT (2.7801 48.47636)
# 43    POINT (5.31187 48.53816)
# 47    POINT (4.51984 51.30761)
# 56   POINT (10.29091 43.73202)
# 59     POINT (21.4989 39.5434)
# 61    POINT (6.33096 50.50493)
# 63   POINT (11.45617 47.80918)
# 78   POINT (12.35729 41.70427)
# 80    POINT (12.1014 55.68068)
# 87   POINT (11.22235 52.08656)
# 89     POINT (14.2504 40.8741)
# 99   POINT (-7.25394 52.94873)
# 107    POINT (12.5365 35.5252)
# 112      POINT (7.5981 47.933)
# 123      POINT (29.61 67.7549)
# 127  POINT (10.74197 45.19775)
# 129   POINT (9.85591 46.81533)
# 132   POINT (5.74355 52.16645)
# 134    POINT (5.9981 50.30496)
# 138   POINT (24.50247 0.81444)
# 139  POINT (13.56515 50.96256)
# 142  POINT (13.41897 56.09763)
# 148  POINT (16.94633 48.68155)
# 149     POINT (3.5957 43.7413)
# 150  POINT (10.45209 51.07941)
# 161    POINT (7.06465 48.6741)
# 162  POINT (24.24301 67.98721)
# 163  POINT (11.64464 55.48587)
# 164  POINT (13.48978 50.96381)
# 166    POINT (13.5881 41.8494)
# 168  POINT (52.97343 13.64393)
# 169   POINT (5.67865 43.24079)
# 173  POINT (23.95952 60.64183)

# %%
import leafmap

# %%
from typing import Union, Optional
import ipyleaflet
import pandas as pd
import os

# %%
def add_labels(
    self,
    data: Union[str, pd.DataFrame],
    column: str,
    font_size: Optional[str] = "12pt",  # Increase this if needed
    font_color: Optional[str] = "black",
    font_family: Optional[str] = "arial",
    font_weight: Optional[str] = "normal",
    x: Optional[str] = "longitude",
    y: Optional[str] = "latitude",
    draggable: Optional[bool] = True,
    x_offset: int = 5,  # Horizontal offset
    y_offset: int = -2,  # Vertical offset
    background_color: Optional[str] = None,  # Background color (None = transparent)
    border_radius: Optional[str] = "4px",  # Rounded corners
    layer_name: Optional[str] = "Labels",
    **kwargs,
):
    """Adds a label layer to the map with dynamically sized background."""

    import warnings
    warnings.filterwarnings("ignore")

    if isinstance(data, pd.DataFrame):
        df = data
        if "geometry" in data.columns or ("geom" in data.columns):
            df[x] = df.centroid.x
            df[y] = df.centroid.y

    elif isinstance(data, str):
        ext = os.path.splitext(data)[1]
        if ext == ".csv":
            df = pd.read_csv(data)
        elif ext in [".geojson", ".json", ".shp", ".gpkg"]:
            try:
                import geopandas as gpd
                df = gpd.read_file(data)
                df[x] = df.centroid.x
                df[y] = df.centroid.y
            except Exception:
                print("geopandas is required to read geojson.")
                return
    else:
        raise ValueError(
            "data must be a pd.DataFrame, gpd.GeoDataFrame, or an ee.FeatureCollection."
        )

    if column not in df.columns:
        raise ValueError(f"column must be one of {', '.join(df.columns)}.")
    if x not in df.columns:
        raise ValueError(f"x must be one of {', '.join(df.columns)}.")
    if y not in df.columns:
        raise ValueError(f"y must be one of {', '.join(df.columns)}.")

    try:
        size = int(font_size.replace("pt", ""))
    except:
        raise ValueError("font_size must be something like '10pt'")

    # Background style with auto-sizing
    bg_style = (
        f"background-color: {background_color}; border-radius: {border_radius}; "
        f"display: inline-block; width: max-content; padding: 1px 4px; line-height: 1;"
        if background_color else ""
    )

    labels = []
    for index in df.index:
        html = f'''
        <div style="font-size: {font_size}; color: {font_color}; font-family: {font_family}; 
                    font-weight: {font_weight}; {bg_style}">
            {df[column][index]}
        </div>'''

        marker = ipyleaflet.Marker(
            location=[df[y][index], df[x][index]],
            icon=ipyleaflet.DivIcon(
                icon_size=(1, 1),
                icon_anchor=(size + x_offset, size + y_offset),  # Offset applied here
                html=html,
                **kwargs,
            ),
            draggable=draggable,
        )
        labels.append(marker)

    layer_group = ipyleaflet.LayerGroup(layers=labels, name=layer_name)
    self.add(layer_group)
    self.labels = layer_group

# %%
# Override leafmap's existing add_labels function with our custom one
import leafmap

leafmap.Map.add_labels = add_labels  # Replace the method with our custom version

# Create the map centered on Europe
m = leafmap.Map(center=(50, 10), zoom=4)
m.add_basemap('Esri.WorldImagery')

# Add markers for the forest sites
m.add_markers(
    forest_sites,
    x='Longitude',
    y='Latitude',
    popup='Name',
    shape='circle',
    radius=3,
    color='#14C9AC',
    fill_opacity=1
)

# Now use the updated add_labels function
m.add_labels(
    forest_sites,
    column="Name",
    font_size="9pt",  # Adjust font size if needed
    font_family="gill sans mt",
    font_color="black",
    x_offset=-5,  # Move labels to the right
    y_offset=-8,  # Adjust vertical position
    background_color="rgba(255, 255, 255, 0.5)",  # Semi-transparent white background
    border_radius="6px",  # Slightly rounded corners
)



m  # Display the updated map
# Out:
# Map(center=[50, 10], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
m.save('forest_sites.html')
